# %%
from sage.all import *
import matplotlib.pyplot as plt
import numpy as np

# ============================================================================
# Dixon Matrix Size Computation
# ============================================================================

def fuss_catalan_number(n, d):
    """
    Compute the Fuss-Catalan number: C_n^(d) = (1/(n(d-1)+1)) * C(nd, n)
    
    Args:
        n: Number parameter
        d: Degree parameter
    
    Returns:
        The Fuss-Catalan number
    """
    if n == 0 or d == 0:
        return 1
    return binomial(n*d, n) / (n*(d-1) + 1)


def dixon_matrix_size_determinant_bound(degree_sequence):
    """
    Compute Dixon matrix size using the Determinant Bound from Theorem 2.
    
    This implements Corollary 1, part 2 from the paper:
    D(F) ≤ det_{1≤i,j≤n-1}((∑_{k=1}^i (d_{n+1-k} - 1) + 1) / (j - i + 1))
    
    Args:
        degree_sequence: List [d_1, d_2, ..., d_n] of polynomial degrees (sorted)
    
    Returns:
        Dixon matrix size bound
    """
    if not degree_sequence:
        return 0
    
    n = len(degree_sequence)
    if n == 1:
        return 1
    
    # Build the matrix for the determinant formula
    # Matrix dimension is (n-1) x (n-1)
    matrix_dim = n - 1
    M = matrix(QQ, matrix_dim, matrix_dim)
    
    for i in range(1, matrix_dim + 1):
        # Compute the cumulative sum: ∑_{k=1}^i (d_{n+1-k} - 1)
        cumsum = sum(degree_sequence[n-k] - 1 for k in range(1, i+1))
        
        for j in range(1, matrix_dim + 1):
            # Compute binomial coefficient (cumsum + 1 choose j - i + 1)
            if j - i + 1 >= 0:
                M[i-1, j-1] = binomial(cumsum + 1, j - i + 1)
            else:
                M[i-1, j-1] = 0
    #print(M)
    return M.determinant()


def compute_dixon_matrix_size(degree_sequence, show_details=False):
    """
    Compute Dixon matrix size for a given degree sequence.
    
    Process:
    1. Sort degrees in descending order and remove the minimum
    2. Reduce each degree by 1 and compute cumulative sums
    3. Use determinant bound to compute Dixon matrix size
    
    Args:
        degree_sequence: Input sequence [a_0, a_1, ..., a_n]
        show_details: Whether to print detailed information
    
    Returns:
        Dixon matrix size
    """
    if not degree_sequence:
        return 0
    
    # Sort in descending order and remove minimum
    sorted_degrees = sorted(degree_sequence, reverse=False)
    #print(sorted_degrees)
    if not sorted_degrees:
        return 0
    
    # Check if all degrees are equal (use Fuss-Catalan formula)
    if sorted_degrees[0] == sorted_degrees[-1]:
        n = len(sorted_degrees)
        d = sorted_degrees[0]
        return fuss_catalan_number(n, d)
    
    # Reduce degrees by 1 for the determinant bound formula
    reduced_degrees = [d - 1 for d in sorted_degrees]
    
    if show_details:
        print(f"Input sequence: {degree_sequence}")
        print(f"Sorted sequence: {sorted_degrees}")
        print(f"Reduced degrees: {reduced_degrees}")
    
    # Compute using determinant bound
    result = dixon_matrix_size_determinant_bound(sorted_degrees)
    
    if show_details:
        print(f"\nDixon matrix size: {result}")
    
    return result


# ============================================================================
# Complexity Estimation Functions
# ============================================================================

def dixon_complexity(degree_sequence, num_vars, omega):
    """
    Compute Dixon resultant complexity for a polynomial system.
    
    Args:
        degree_sequence: List of polynomial degrees
        num_vars: Total number of variables
        omega: Matrix multiplication exponent (typically 2)
    
    Returns:
        log_2 of the complexity
    """
    matrix_size = compute_dixon_matrix_size(degree_sequence)
    
    # Compute the number of equations
    m = len(degree_sequence)
    
    # Determine the degree multiplier d
    if m == num_vars + 1:
        d = 1
    elif m == num_vars:
        d = sum(degree_sequence)
    elif m < num_vars:
        d = (sum(degree_sequence) + 1)^(num_vars - m + 1)
    else:
        return 0
    
    # Total complexity: d * (matrix_size)^omega
    return log(d * matrix_size^omega, 2).n()


# ============================================================================
# Poseidon/Poseidon2 Complexity Analysis
# ============================================================================

def compute_equation_params(t, c, d, alpha, rounds_full, rounds_partial):
    """
    Compute equation parameters for Poseidon elimination strategies.
    
    Returns:
        Tuple of (num_equations, degree)
    """
    return d, alpha^(rounds_full + rounds_partial)


def compute_equation_params_strategy2(t, c, d, alpha, rounds_full, rounds_partial):
    """Strategy 2: Using more rounds"""
    return floor(t * (rounds_full/2) + d + rounds_partial - c), alpha


def compute_equation_params_strategy3(t, c, d, alpha, rounds_full, rounds_partial):
    """Strategy 3: Subspace with two groups"""
    if rounds_partial < t - 1:
        k = 0
    else:
        k = floor((rounds_partial - t + 1) / 2)
    return 2*t, alpha^(rounds_full/2 + floor((rounds_partial - t + 1)/2) / 2)


def compute_equation_params_strategy3_variant(t, c, d, alpha, rounds_full, rounds_partial):
    """Strategy 3 variant"""
    return t-1, alpha^(t-1)


def compute_equation_params_strategy4(t, c, d, alpha, rounds_full, rounds_partial):
    """Strategy 4: Another subspace approach"""
    if rounds_partial < t - (c + d):
        k = 0
    else:
        k = rounds_partial - (t - (c + d))
    return t, floor(sqrt(d/t) * alpha^(rounds_full/2 + k/2))


def compute_equation_params_strategy5(t, c, d, alpha, rounds_full, rounds_partial):
    """Strategy 5: Variant of strategy 4"""
    if rounds_partial < t - (c + d):
        k = 0
    else:
        k = rounds_partial - (t - (c + d))
    return d, floor(sqrt(d/t) * alpha^(rounds_full/2 + k/2))


# Degree of regularity computations
def degree_of_regularity(num_eqs, degree):
    """Compute degree of regularity"""
    return num_eqs * (degree - 1) + 1


def degree_of_regularity_two_groups(d1, d2):
    """Degree of regularity for two groups"""
    return d1 + d2 - 1


# ============================================================================
# F4 Gröbner Basis Complexity
# ============================================================================

def f4_complexity(num_eqs, dreg, omega):
    """
    F4 Gröbner basis complexity.
    
    Args:
        num_eqs: Number of equations
        dreg: Degree of regularity
        omega: Matrix multiplication exponent
    
    Returns:
        log_2 of complexity
    """
    return log(binomial(num_eqs + dreg, num_eqs)^omega, 2).n()


def f4_complexity_with_degree(num_eqs, degree, omega):
    """F4 complexity when given degree directly"""
    dreg = degree_of_regularity(num_eqs, degree)
    return f4_complexity(num_eqs, dreg, omega)


def fglm_complexity(num_eqs, degree, omega):
    """FGLM algorithm complexity"""
    return log(num_eqs * degree^(omega * num_eqs), 2).n()


# ============================================================================
# Strategy-specific complexity functions
# ============================================================================

def f4_strategy1(t, c, d, alpha, rounds_full, rounds_partial, omega):
    """F4 complexity for strategy 1 (direct approach)"""
    num_eqs, degree = compute_equation_params(t, c, d, alpha, rounds_full, rounds_partial)
    dreg = degree_of_regularity(num_eqs, degree)
    return f4_complexity(num_eqs, dreg, omega)


def f4_strategy2(t, c, d, alpha, rounds_full, rounds_partial, omega):
    """F4 complexity for strategy 2"""
    num_eqs, degree = compute_equation_params_strategy2(t, c, d, alpha, rounds_full, rounds_partial)
    dreg = degree_of_regularity(num_eqs, degree)
    return f4_complexity(num_eqs, dreg, omega)


def f4_strategy3(t, c, d, alpha, rounds_full, rounds_partial, omega):
    """F4 complexity for strategy 3 (subspace approach)"""
    num_eqs1, degree1 = compute_equation_params_strategy4(t, c, d, alpha, rounds_full, rounds_partial)
    dreg1 = degree_of_regularity(num_eqs1, degree1)
    
    num_eqs2, degree2 = compute_equation_params_strategy5(t, c, d, alpha, rounds_full, rounds_partial)
    dreg2 = degree_of_regularity(num_eqs2, degree2)
    
    combined_dreg = degree_of_regularity_two_groups(dreg1, dreg2)
    total_eqs = num_eqs1 + num_eqs2
    
    return f4_complexity(total_eqs, combined_dreg, omega)


def f4_strategy4(t, c, d, alpha, rounds_full, rounds_partial, omega):
    """F4 complexity for strategy 4"""
    num_eqs, degree = compute_equation_params_strategy3(t, c, d, alpha, rounds_full, rounds_partial)
    dreg = degree_of_regularity(num_eqs, degree)
    return f4_complexity(num_eqs, dreg, omega)


def dixon_strategy1(t, c, d, alpha, rounds_full, rounds_partial, omega):
    """Dixon complexity for strategy 1"""
    num_eqs, degree = compute_equation_params(t, c, d, alpha, rounds_full, rounds_partial)
    return dixon_complexity([degree] * num_eqs, num_eqs, omega)


def dixon_strategy2(t, c, d, alpha, rounds_full, rounds_partial, omega):
    """Dixon complexity for strategy 2"""
    num_eqs, degree = compute_equation_params_strategy2(t, c, d, alpha, rounds_full, rounds_partial)
    return dixon_complexity([degree] * num_eqs, num_eqs, omega)


def dixon_strategy3(t, c, d, alpha, rounds_full, rounds_partial, omega):
    """Dixon complexity for strategy 3"""
    num_eqs1, degree1 = compute_equation_params_strategy4(t, c, d, alpha, rounds_full, rounds_partial)
    num_eqs2, degree2 = compute_equation_params_strategy5(t, c, d, alpha, rounds_full, rounds_partial)
    degree_list = [degree1] * num_eqs1 + [degree2] * num_eqs2
    return dixon_complexity(degree_list, num_eqs1 + num_eqs2, omega)


def dixon_strategy4(t, c, d, alpha, rounds_full, rounds_partial, omega):
    """Dixon complexity for strategy 4"""
    num_eqs, degree = compute_equation_params_strategy3(t, c, d, alpha, rounds_full, rounds_partial)
    return dixon_complexity([degree] * num_eqs, num_eqs, omega)


def compute_all_poseidon_complexities(t, c, d, alpha, rounds_full, rounds_partial, omega):
    """
    Compute all F4 and Dixon complexities for Poseidon.
    
    Returns:
        Dictionary with all complexity values
    """
    return {
        'f4_io': f4_strategy1(t, c, d, alpha, rounds_full, rounds_partial, omega),
        'f4_subspace_o': f4_strategy3(t, c, d, alpha, rounds_full, rounds_partial, omega),
        'f4_subspace_i': f4_strategy4(t, c, d, alpha, rounds_full, rounds_partial, omega),
        'dixon_io': dixon_strategy1(t, c, d, alpha, rounds_full, rounds_partial, omega),
        'dixon_subspace_o': dixon_strategy3(t, c, d, alpha, rounds_full, rounds_partial, omega),
        'dixon_subspace_i': dixon_strategy4(t, c, d, alpha, rounds_full, rounds_partial, omega),
    }


# ============================================================================
# Visualization
# ============================================================================
def plot_poseidon_complexity_comparison(t=8, c=3, d=3, alpha=3, rounds_full=6, omega=2, 
                                       rounds_partial_range=range(1, 11)):
    """
    Generate complexity comparison plot for Poseidon and Poseidon2.
    Similar to Fig. 3 in the paper.
    
    Args:
        t: State size
        c: Capacity
        d: Rate
        alpha: S-box exponent
        rounds_full: Number of full rounds
        omega: Matrix multiplication exponent
        rounds_partial_range: Range of partial rounds to analyze
    """
    # Set font to serif (will use Liberation Serif or similar)
    plt.rcParams['font.family'] = 'serif'
    plt.rcParams['font.serif'] = ['Liberation Serif', 'DejaVu Serif', 'Times New Roman']
    plt.rcParams['mathtext.fontset'] = 'dejavuserif'
    plt.rcParams['xtick.labelsize'] = 12 
    plt.rcParams['ytick.labelsize'] = 12 
    # Storage for results
    results = {
        'rounds_partial': [],
        'f4_io': [], 'f4_subspace_o': [], 'f4_subspace_i': [],
        'dixon_io': [], 'dixon_subspace_o': [], 'dixon_subspace_i': []
    }
    
    # Compute complexities for each number of partial rounds
    for rp in rounds_partial_range:
        results['rounds_partial'].append(rp)
        complexities = compute_all_poseidon_complexities(t, c, d, alpha, rounds_full, rp, omega)
        for key, value in complexities.items():
            results[key].append(float(value))
    
    # Create the plot
    plt.figure(figsize=(10, 6))
    
    # Plot F4 strategies
    plt.plot(results['rounds_partial'], results['f4_io'], 
             'o-', color='blue', label='F4 + I/O', linewidth=2)
    plt.plot(results['rounds_partial'], results['f4_subspace_o'], 
             'o-', color='red', label='F4 + subspace-O', linewidth=2)
    plt.plot(results['rounds_partial'], results['f4_subspace_i'], 
             'o-', color='green', label='F4 + subspace-I', linewidth=2)
    
    # Plot Dixon strategies (dashed lines)
    plt.plot(results['rounds_partial'], results['dixon_io'], 
             's--', color='blue', label='Dixon + I/O', linewidth=2)
    plt.plot(results['rounds_partial'], results['dixon_subspace_o'], 
             's--', color='red', label='Dixon + subspace-O', linewidth=2)
    plt.plot(results['rounds_partial'], results['dixon_subspace_i'], 
             's--', color='green', label='Dixon + subspace-I', linewidth=2)
    
    plt.xlabel(r'$R_P$ (Number of Partial Rounds)', fontsize=16)
    plt.ylabel(r'Complexity ($\approx \log_2$ field operations)', fontsize=16)
    plt.title(f'Complexity Comparison for Poseidon (t={t}, c=d={c}, α={alpha}, ω={omega:.2f})', 
              fontsize=18)
    plt.legend(loc='upper left', fontsize=14)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    
    return plt

# ============================================================================
# Example Usage
# ============================================================================

if __name__ == "__main__":
    # Set parameters for Poseidon
    t = 8      # State size
    c = 3      # Capacity
    d = 3      # Rate
    alpha = 3  # S-box exponent
    rounds_full = 6  # Number of full rounds
    omega = 2.81  # Matrix multiplication exponent
    
    print("=" * 70)
    print("Poseidon Complexity Analysis")
    print("=" * 70)
    print(f"Parameters: t={t}, c={c}, d={d}, α={alpha}, R_F={rounds_full}, ω={omega:.2f}")
    print("=" * 70)
    
    # Analyze different numbers of partial rounds
    '''
    for rounds_partial in range(2, 30, 2):
        complexities = compute_all_poseidon_complexities(t, c, d, alpha, rounds_full, 
                                                         rounds_partial, omega)
        print(f"\nR_P = {rounds_partial}:")
        print(f"  F4 (I/O): {complexities['f4_io']:.2f}")
        print(f"  F4 (subspace-O): {complexities['f4_subspace_o']:.2f}")
        print(f"  F4 (subspace-I): {complexities['f4_subspace_i']:.2f}")
        print(f"  Dixon (I/O): {complexities['dixon_io']:.2f}")
        print(f"  Dixon (subspace-O): {complexities['dixon_subspace_o']:.2f}")
        print(f"  Dixon (subspace-I): {complexities['dixon_subspace_i']:.2f}")
    '''
    print("\n" + "=" * 70)
    print("Generating complexity comparison plot...")
    print("=" * 70)
    
    # Generate and display the plot
    plot = plot_poseidon_complexity_comparison(t, c, d, alpha, rounds_full, omega, range(2, 25, 2))
    plot.savefig('poseidon_complexity_comparison.png', dpi=300, bbox_inches='tight')
    print("Plot saved as 'poseidon_complexity_comparison.png'")
    plot.show()
# Out:
# ...
# Poseidon Complexity Analysis
# ...
# Parameters: t=8, c=3, d=3, α=3, R_F=6, ω=2.81
# ...
#
# ...
# Generating complexity comparison plot...
# ...
# Plot saved as 'poseidon_complexity_comparison.png'

# %%
# ============================================================================
# Vision Algorithm Complexity Analysis
# ============================================================================

def vision_f4_complexity(n, dreg, omega):
    """
    F4 Gröbner basis complexity for Vision algorithm.
    
    Args:
        n: Number of equations
        dreg: Degree of regularity
        omega: Matrix multiplication exponent
    
    Returns:
        log_2 of complexity
    """
    return log(binomial(n + dreg, n)^omega, 2).n()


def vision_dixon_complexity(n, d, omega):
    """
    Dixon resultant complexity for Vision algorithm.
    
    Args:
        n: Number of variables
        d: Degree of polynomials
        omega: Matrix multiplication exponent
    
    Returns:
        log_2 of complexity
    """
    return dixon_complexity([d] * n, n, omega)


def compute_vision_complexities(max_rounds=27, omega=2):
    """
    Compute complexities for Vision algorithm.
    
    Args:
        max_rounds: Maximum number of rounds to compute
        omega: Matrix multiplication exponent
    
    Returns:
        Dictionary with complexity data for different methods
    """
    results = {
        'rounds': [],
        'dixon': [],
        'groebner_theoretical': [],
        'groebner_overdefined': []
    }
    
    # Overdefined Gröbner basis data from the paper
    groebner_overdefined_data = {
        2: 31, 4: 53, 6: 74, 8: 95, 10: 115, 12: 136,
        14: 156, 16: 176, 18: 197, 20: 217, 22: 237,
        24: 250, 26: 271
    }
    
    for r in range(1, max_rounds):
        results['rounds'].append(r)
        
        # Compute degree parameters based on round parity
        if r % 2 == 0:
            d8 = 2 * r - 2
            d4 = 1
            d2 = 2 * r
        else:
            d8 = 2 * r - 2
            d4 = 1
            d2 = 2 * r
        
        # Theoretical Gröbner basis
        dreg = d8 * 7 + d4 * 3 + d2 * 1 - 1
        n = 4 * r - 1
        results['groebner_theoretical'].append(vision_f4_complexity(n, dreg, omega))
        
        # Dixon resultant
        d = 2^(4 * r)
        n_dixon = 2
        results['dixon'].append(vision_dixon_complexity(n_dixon, d, omega))
        
        # Overdefined Gröbner basis (from paper data)
        if r in groebner_overdefined_data:
            results['groebner_overdefined'].append((r, groebner_overdefined_data[r]))
    
    return results


def plot_vision_complexity_comparison(max_rounds=27, omega=2):
    """
    Generate complexity comparison plot for Vision algorithm.
    
    Args:
        max_rounds: Maximum number of rounds
        omega: Matrix multiplication exponent
    
    Returns:
        matplotlib plot object
    """
    # Set font to serif
    plt.rcParams['font.family'] = 'serif'
    plt.rcParams['font.serif'] = ['Liberation Serif', 'DejaVu Serif', 'Times New Roman']
    plt.rcParams['mathtext.fontset'] = 'dejavuserif'
    plt.rcParams['xtick.labelsize'] = 16
    plt.rcParams['ytick.labelsize'] = 16
    
    # Compute complexities
    results = compute_vision_complexities(max_rounds, omega)
    
    # Create the plot
    plt.figure(figsize=(10, 6))
    
    # Plot Dixon resultant
    plt.plot(results['rounds'], results['dixon'],
             'o-', color='red', linewidth=3, markersize=4,
             markevery=2, label='Dixon resultant')
    
    # Plot Gröbner basis (theoretical)
    plt.plot(results['rounds'], results['groebner_theoretical'],
             's-', color='blue', linewidth=3, markersize=4,
             markevery=3, alpha=0.5, label='Gröbner (theoretical)')
    
    # Plot Gröbner basis (Overdefined) - from paper data
    overdefined_rounds = [x[0] for x in results['groebner_overdefined']]
    overdefined_complexity = [x[1] for x in results['groebner_overdefined']]
    plt.plot(overdefined_rounds, overdefined_complexity,
             '^-', color='green', linewidth=3, markersize=5,
             markevery=1, label='Gröbner (Overdefined)')
    
    # Add security level lines
    plt.axhline(y=128, color='gray', linestyle='--', linewidth=1, alpha=0.7)
    plt.text(24, 132, '128-bit', fontsize=14, color='gray')
    
    plt.axhline(y=256, color='gray', linestyle='--', linewidth=1, alpha=0.7)
    plt.text(24, 260, '256-bit', fontsize=14, color='gray')
    
    plt.xlabel('Number of Rounds', fontsize=18)
    plt.ylabel(r'Complexity ($\log_2$ field operations)', fontsize=18)
    plt.title(r'Complexity comparison for Vision ($\omega = 2$)', fontsize=20)
    plt.xlim(0, max_rounds)
    plt.ylim(0, 350)
    plt.xticks(range(0, max_rounds + 1, 4))
    plt.yticks(range(0, 400, 50))
    plt.grid(True, alpha=0.3)
    plt.legend(loc='lower right', fontsize=16)
    plt.tight_layout()
    
    return plt


# Generate and save the Vision plot
if __name__ == "__main__":
    print("=" * 70)
    print("Vision Algorithm Complexity Analysis")
    print("=" * 70)
    
    plot_vision = plot_vision_complexity_comparison(max_rounds=27, omega=2)
    plot_vision.savefig('vision_complexity_comparison.png', dpi=300, bbox_inches='tight')
    print("Vision plot saved as 'vision_complexity_comparison.png'")
    plot_vision.show()
# Out:
# ...
# Vision Algorithm Complexity Analysis
# ...
# Vision plot saved as 'vision_complexity_comparison.png'

# %%
# ============================================================================
# XHash Algorithm Complexity Analysis
# ============================================================================

def xhash_f4_complexity(n, dreg, omega):
    """F4 Gröbner basis complexity for XHash."""
    return log(binomial(n + dreg, n)^omega, 2).n()


def xhash_dixon_complexity(n, d, omega):
    """Dixon resultant complexity for XHash."""
    return dixon_complexity([d] * n, n, omega)


def xhash_reduce_complexity(n, d, omega):
    """Reduction complexity for XHash."""
    return log(d^n * d^2 * ((2*d - 1) / d)^(n + 2), 2).n()


def compute_xhash_complexities(max_steps=6, omega=2.81):
    """
    Compute complexities for XHash algorithm using different methods.
    
    Args:
        max_steps: Maximum number of steps
        omega: Matrix multiplication exponent (default 2.81)
    
    Returns:
        Dictionary with complexity data for all methods
    """
    results = {
        'steps': [],
        'groebner': [],
        'method1': [],
        'method3': [],
        'cico2': [],
        'cico3': [],
        'cico4': []
    }
    
    for r in range(max_steps):
        step = r + 1
        results['steps'].append(step)
        
        n = 12 * step
        d = 7
        dreg = n * (d - 1) + 1
        
        # Powers of d for Method 1+3 methods
        dI = d^n
        dI2 = d^(n - 1)
        dI3 = d^(n - 2)
        dI4 = d^(n - 3)
        
        # CICO-1: Gröbner basis
        results['groebner'].append(xhash_f4_complexity(n, dreg, omega))
        
        # CICO-1: Method 1 (Direct Dixon)
        results['method1'].append(xhash_dixon_complexity(n, d, omega))
        
        # CICO-1: Method 3 (Reduction)
        results['method3'].append(xhash_reduce_complexity(n, d, omega))
        
        # CICO-2: Method 1+3
        results['cico2'].append(xhash_dixon_complexity(2, dI2, omega))
        
        # CICO-3: Method 1+3
        results['cico3'].append(xhash_dixon_complexity(3, dI3, omega))
        
        # CICO-4: Method 1+3
        results['cico4'].append(xhash_dixon_complexity(4, dI4, omega))
    
    return results


def plot_xhash_complexity_comparison(max_steps=6, omega=2.81):
    """
    Generate complexity comparison plot for XHash algorithm.
    
    Args:
        max_steps: Maximum number of steps
        omega: Matrix multiplication exponent
    
    Returns:
        matplotlib plot object
    """
    # Set font to serif
    plt.rcParams['font.family'] = 'serif'
    plt.rcParams['font.serif'] = ['Liberation Serif', 'DejaVu Serif', 'Times New Roman']
    plt.rcParams['mathtext.fontset'] = 'dejavuserif'
    plt.rcParams['xtick.labelsize'] = 12
    plt.rcParams['ytick.labelsize'] = 12
    
    # Compute complexities
    results = compute_xhash_complexities(max_steps, omega)
    
    # Create the plot
    fig_width = 0.85 * 12  # Approximate textwidth conversion
    fig_height = 0.5 * fig_width
    plt.figure(figsize=(fig_width, fig_height))
    
    # Plot all methods
    plt.plot(results['steps'], results['groebner'],
             'o-', color='orange', linewidth=2, markersize=6,
             label='CICO-1 (Gröbner basis)')
    
    plt.plot(results['steps'], results['method1'],
             's-', color='blue', linewidth=2, markersize=6,
             label='CICO-1 (Method 1)')
    
    plt.plot(results['steps'], results['method3'],
             '^-', color='green', linewidth=2, markersize=6,
             label='CICO-1 (Method 3)')
    
    plt.plot(results['steps'], results['cico2'],
             'D--', color='red', linewidth=2, markersize=6,
             label='CICO-2 (Method 1+3)')
    
    plt.plot(results['steps'], results['cico3'],
             'p--', color='purple', linewidth=2, markersize=7,
             label='CICO-3 (Method 1+3)')
    
    plt.plot(results['steps'], results['cico4'],
             '*--', color='brown', linewidth=2, markersize=9,
             label='CICO-4 (Method 1+3)')
    
    plt.xlabel('Number of Steps', fontsize=14)
    plt.ylabel(r'Complexity ($\log_2$ field operations)', fontsize=14)
    plt.title(r'Complexity comparison for XHash ($\omega = 2.81$)', fontsize=16)
    plt.xlim(0.5, max_steps + 0.5)
    plt.ylim(0, 1900)
    plt.xticks(range(1, max_steps + 1))
    plt.grid(True, linestyle='--', alpha=0.3, color='gray')
    plt.legend(loc='upper left', fontsize=13)
    plt.tight_layout()
    
    return plt


# Generate and save the XHash plot
if __name__ == "__main__":
    print("\n" + "=" * 70)
    print("XHash Algorithm Complexity Analysis")
    print("=" * 70)
    
    plot_xhash = plot_xhash_complexity_comparison(max_steps=6, omega=2.81)
    plot_xhash.savefig('xhash_complexity_comparison.png', dpi=300, bbox_inches='tight')
    print("XHash plot saved as 'xhash_complexity_comparison.png'")
    plot_xhash.show()
# Out:
# ...
# XHash Algorithm Complexity Analysis
# ...
# XHash plot saved as 'xhash_complexity_comparison.png'
