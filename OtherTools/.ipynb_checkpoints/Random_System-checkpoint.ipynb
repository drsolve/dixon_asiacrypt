# %%
### from sage.all import *
import itertools


def random_polynomial_over_finite_field(n, d, p, m, r):
    F = GF(p, names='t')
    R = PolynomialRing(F, n, 'x', order='lex')
    x = R.gens()
    ps = []
    all_exponents = list(itertools.product(range(d + 1), repeat=n))
    valid_exponents = [exp for exp in all_exponents if sum(exp) <= d] #all_exponents#
    r0 = r
    if r > binomial(n+d,d) or r == 0:
        r0 = binomial(n+d,d)
    for i in range(m):
        poly = 0
        used_indices = set()
        while len(used_indices) < r0:
            idx = randint(0, len(valid_exponents) - 1)
            if idx not in used_indices:
                exponents = valid_exponents[idx]
                coefficient = F.random_element()
                term = coefficient * prod([x[j] ** exponents[j] for j in range(n)])
                poly += term
                used_indices.add(idx)
        ps.append(poly)
    return ps


# Example usage
r = 0   # monomial number
n = 5   # number of variables
d = 2   # degree of polynomial
p = 65537  # characteristic of the finite field
m = 5   # number of equations

ps = random_polynomial_over_finite_field(n, d, p, m, r)
ps
# Out:
# [-3858*x0^2 - 12690*x0*x1 - 27015*x0*x2 + 12214*x0*x3 + 30185*x0*x4 + 18626*x0 - 32658*x1^2 + 30872*x1*x2 + 4835*x1*x3 + 6459*x1*x4 - 21666*x1 - 26496*x2^2 + 5923*x2*x3 + 8098*x2*x4 - 31614*x2 - 10795*x3^2 + 17793*x3*x4 - 15311*x3 + 21990*x4^2 + 13797*x4 + 21241,
#  -19810*x0^2 + 11193*x0*x1 - 26701*x0*x2 + 3063*x0*x3 - 30281*x0*x4 - 10993*x0 + 30664*x1^2 - 15179*x1*x2 + 20192*x1*x3 - 28934*x1*x4 + 2084*x1 + 9925*x2^2 - 6023*x2*x3 + 22838*x2*x4 + 6270*x2 + 875*x3^2 + 2645*x3*x4 + 2673*x3 + 10448*x4^2 + 14947*x4 - 7297,
#  -31846*x0^2 + 8443*x0*x1 - 26408*x0*x2 + 30828*x0*x3 - 30186*x0*x4 - 26812*x0 - 1588*x1^2 + 22513*x1*x2 + 9045*x1*x3 - 19249*x1*x4 - 2670*x1 + 22976*x2^2 + 19487*x2*x3 + 22457*x2*x4 - 20840*x2 + 26196*x3^2 - 5917*x3*x4 + 31410*x3 + 15093*x4^2 + 14630*x4 + 2807,
#  -7737*x0^2 + 7097*x0*x1 + 24860*x0*x2 + 4295*x0*x3 + 8477*x0*x4 - 3338*x0 - 13848*x1^2 - 20471*x1*x2 + 6528*x1*x3 - 31992*x1*x4 + 14193*x1 + 8181*x2^2 - 25832*x2*x3 - 7588*x2*x4 - 14048*x2 - 27062*x3^2 - 15012*x3*x4 + 14975*x3 - 14442*x4^2 - 19393*x4 + 12424,
#  13071*x0^2 + 31493*x0*x1 - 18393*x0*x2 - 12577*x0*x3 + 15836*x0*x4 - 22676*x0 + 6963*x1^2 - 29930*x1*x2 + 28323*x1*x3 - 12347*x1*x4 + 1216*x1 + 32569*x2^2 + 19354*x2*x3 + 5598*x2*x4 + 30007*x2 + 18156*x3^2 - 15952*x3*x4 - 5154*x3 - 14342*x4^2 - 10917*x4 - 7025]
