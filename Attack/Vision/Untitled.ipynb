# %%
load("../../drsolve/drsolve_sage_interface.sage")


def vision_3r_attack(dixon_path="drsolve", live_output=True):
    set_dixon_path(dixon_path)

    R0.<u> = GF(2)[]
    K.<z8> = GF(2^8, modulus=u^8 + u^4 + u^3 + u^2 + 1)
    field = K
    R = PolynomialRing(K, names=["x0", "x1", "x2", "x3", "x4", "x5", "x6", "x7", "x8", "x9", "x10"])
    x0, x1, x2, x3, x4, x5, x6, x7, x8, x9, x10 = R.gens()

    p0 = (z8^7 + z8^5 + z8^3)*x1^4*x3^4 + (z8^7 + z8^6 + z8^5 + z8^4 + z8^3 + z8^2)*x2^4*x3^4 + (z8^6 + z8^3 + z8^2 + z8)*x1^4*x3^2 + (z8^6 + z8^5 + z8^3 + 1)*x2^4*x3^2 + (z8^6 + z8^3 + z8^2 + z8)*x1^2*x3^4 + (z8^6 + z8^5 + z8^3 + 1)*x2^2*x3^4 + (z8^7 + z8^6 + z8^5 + 1)*x1^4*x3 + (z8^4 + z8^3 + z8^2 + z8 + 1)*x2^4*x3 + (z8^7 + z8^6 + z8^5 + 1)*x1*x3^4 + (z8^4 + z8^3 + z8^2 + z8 + 1)*x2*x3^4 + (z8^6 + z8^3 + z8 + 1)*x1^2*x3^2 + (z8^7 + z8^6 + z8^5)*x2^2*x3^2 + (z8^7 + z8^6 + z8^4 + z8^3 + z8^2 + 1)*x3^4 + (z8^7 + z8^6 + z8^5 + z8^4 + z8^3 + z8 + 1)*x1^2*x3 + (z8^3)*x2^2*x3 + (z8^7 + z8^6 + z8^5 + z8^4 + z8^3 + z8 + 1)*x1*x3^2 + (z8^3)*x2*x3^2 + (z8^6 + z8^3 + z8^2 + z8)*x1*x3 + (z8^6 + z8^5 + z8^3 + 1)*x2*x3 + (z8^6 + z8^5 + z8^4 + 1)*x3^2 + (z8^7 + z8^5 + z8^2)*x3 + 1
    p1 = (z8^7 + z8^6 + z8^5 + z8^2 + 1)*x1^4*x4^4 + (z8^7 + z8^5 + z8^4 + 1)*x2^4*x4^4 + (z8^7 + z8^6 + z8^4 + z8)*x1^4*x4^2 + (z8^7 + z8^6 + z8^5 + z8^4 + z8^2 + 1)*x2^4*x4^2 + (z8^7 + z8^6 + z8^4 + z8)*x1^2*x4^4 + (z8^7 + z8^6 + z8^5 + z8^4 + z8^2 + 1)*x2^2*x4^4 + (z8^5 + z8^4 + z8^3 + z8^2 + z8)*x1^4*x4 + (z8^7 + z8^6)*x2^4*x4 + (z8^5 + z8^4 + z8^3 + z8^2 + z8)*x1*x4^4 + (z8^7 + z8^6)*x2*x4^4 + (z8^7 + z8^6 + z8^4 + z8^3 + z8^2 + 1)*x1^2*x4^2 + (z8^6 + z8^5 + z8^4 + z8^2 + z8)*x2^2*x4^2 + (z8^7 + z8^5 + z8^3)*x4^4 + (z8^4)*x1^2*x4 + (z8^7 + z8^6 + z8^5 + z8 + 1)*x2^2*x4 + (z8^4)*x1*x4^2 + (z8^7 + z8^6 + z8^5 + z8 + 1)*x2*x4^2 + (z8^7 + z8^6 + z8^4 + z8)*x1*x4 + (z8^7 + z8^6 + z8^5 + z8^4 + z8^2 + 1)*x2*x4 + (z8^6 + z8^3 + z8^2 + z8)*x4^2 + (z8^7 + z8^6 + z8^5 + 1)*x4 + 1
    p4 = z8*x0*x1 + (z8^7 + z8^6 + z8^4 + z8^2 + z8)*x1 + 1
    p5 = (z8^2 + z8)*x0*x2 + (z8^6 + z8^4 + z8)*x2 + 1
    p6 = z8*x3*x5 + (z8 + 1)*x4*x5 + (z8^6 + z8^2 + z8)*x5 + 1
    p7 = (z8^2 + z8)*x3*x6 + (z8^2 + z8 + 1)*x4*x6 + (z8^7 + z8^3 + z8^2 + 1)*x6 + 1
    p8 = z8*x7*x9 + (z8 + 1)*x8*x9 + (z8^5 + z8^4 + z8)*x9 + 1
    p9 = (z8^2 + z8)*x7*x10 + (z8^2 + z8 + 1)*x8*x10 + (z8^5 + z8^4 + z8^3 + z8 + 1)*x10 + 1
    p10 = (z8^4 + z8^3 + z8^2)*x9^4 + (z8^4 + z8)*x10^4 + (z8^7 + z8^6 + z8^4 + z8^3 + z8^2 + z8 + 1)*x9^2 + (z8^5 + z8^4 + z8^3 + z8^2 + z8)*x10^2 + (z8^6 + z8^3 + z8^2 + 1)*x9 + (z8^7 + z8^6 + z8^5 + z8^2 + 1)*x10 + (z8^7 + z8^6 + z8^5 + z8^3 + z8^2 + z8)

    common = dict(
        field_size=field,
        live_output=live_output,
        verbosity=1,
        time=True,
    )
    subres = dict(common, resultant_method="subres")
    dixon = dict(common, resultant_method="dixon")

    print("=== Vision Attack using Sage interface ===")
    total_start = walltime()
    r1 = DixonRes([p4, p5], [x0], **subres)
    r2 = DixonRes([r1, p0, p1], [x1, x2], **dixon)
    r3 = DixonRes([r2, p6, p7], [x3, x4], **dixon)
    s1 = DixonRes([p9, p10], [x10], **subres)
    s2 = DixonRes([s1, p8], [x9], **subres)
    s3 = DixonRes([s2, p3], [x8], **subres)
    s4 = DixonRes([s3, p2], [x7], **subres)
    d = DixonRes([r3, s4], [x5], **subres)
    print("Total solve time: %.6f s" % walltime(total_start))
    return d


if __name__ == "__main__":
    vision_3r_attack()
# Out:
# === Vision Attack using Sage interface ===
# ...
# DRSolve v0.4.5
# FLINT version: 3.6.0 (Recommended: 3.6.0)
# PML support: ENABLED
# ...
# Reading from file: /tmp/drsolve_n0mobq0h.in
# Detected file mode: elimination
# Using custom field polynomial: z8^8 + z8^4 + z8^3 + z8^2 + 1
# Generator variable: z8
# === Subresultant Resultant Computation ===
# Field: F_2^8 (size 256)
# Field extension generator: t
# Note: in extension fields, symbol 't' is interpreted as the field generator.
# Task: Subresultant resultant  |  Equations: 2  |  Eliminate: x0
# --------------------------------
# Subresultant: computing resultant eliminating x0.
#   Input summary: terms=(3, 3), deg_x0=(1, 1), remaining vars=2 [x1, x2]
# Subresultant: resultant computed.
#   Resultant summary: 3 terms, total degree 2, remaining variables: x1, x2
#   Final Resultant = x1*x2 + (z8^7 + z8^6 + z8 + 1)*x1 + (z8^6 + z8^4 + z8^3)*x2
#
# Result saved to: /tmp/drsolve_fmanlbbk.out
# ...
